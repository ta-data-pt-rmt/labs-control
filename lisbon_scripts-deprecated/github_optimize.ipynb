# %%
# import pandas as pd
# import requests
# import openpyxl
# import time

# %%
alias = {'ana silva': 'anasilva',
        'matias': 'anamatias',
        'gusto': 'augusto',
        'muniz': 'barbara',
        'cecil': 'cecilia',   
        'eun': 'eunice',
        'gonçalo': 'goncalo', 
        'joao': 'joao',
        'mig': 'miguel',
        'etazevedo' : 'eunice'}

# %% [markdown]
# # Week 1

# %%
labs_week1 = {'lab-list-comprehensions' : 'B3',
            'lab-tuple-set-dict' : 'B4',
            'lab-string-operations' : 'B5',
            'lab-numpy' : 'B6',
            'lab-intro-pandas' : 'B7'}

# %%
for labs in labs_week1:
    print(labs)
    time.sleep(5)
    response = requests.get('https://api.github.com/repos/ta-data-lis/' + labs + '/pulls')
    data = pd.DataFrame(response.json())
    if 'title' in data:
        pr = data['title']
        pr_name = [a.split(']')[1].strip() for a in pr if len(a.split(']')) > 1]

        # print(pr)

        names = []

        for x in alias:
            for a in pr_name:
                if a.lower().find(x) != -1:
                    names.append(alias[x])

        print(names)

        book = openpyxl.load_workbook('labs.xlsx')

        for name in names:
            sheet = book[name]
            sheet[labs_week1[labs]] = 'Delivered'

        book.save('Labs.xlsx')
# Out:
# 0    [lab-list-comprehensions]Augusto Eira
# Name: title, dtype: object
# ['augusto']
# 0    arturspriet
# Name: title, dtype: object
# []
# 0    arthurspriet
# Name: title, dtype: object
# []
# 0    [lab-intro-pandas] [renato] first attempt
# Name: title, dtype: object
# []

# %% [markdown]
# # Week 2

# %%
labs_week2 = {'lab-mysql-first-queries' : 'D3',
            'lab-mysql-select' : 'D4',
            'lab-mysql' : 'D5',
            'lab-dataframe-calculations' : 'D6',
            'lab-advanced-pandas' : 'D7',
            'lab-import-export' : 'D8', 
            'lab-data-cleaning' : 'D9',
            'lab-lambda-functions' : 'D10'}

# %%
for labs in labs_week2:
    print(labs)
    time.sleep(5)
    response = requests.get('https://api.github.com/repos/ta-data-lis/' + labs + '/pulls')
    data = pd.DataFrame(response.json())
    if 'title' in data:
        pr = data['title']
        pr_name = [a.split(']')[1].strip() for a in pr if len(a.split(']')) > 1]

        # print(pr)

        names = []

        for x in alias:
            for a in pr_name:
                if a.lower().find(x) != -1:
                    names.append(alias[x])

        print(names)

        book = openpyxl.load_workbook('labs.xlsx')

        for name in names:
            sheet = book[name]
            sheet[labs_week2[labs]] = 'Delivered'

        book.save('Labs.xlsx')
# Out:
# lab-mysql-first-queries
# lab-mysql-select
# []
# lab-mysql
# []
# lab-dataframe-calculations
# []
# lab-advanced-pandas
# []
# lab-import-export
# []
# lab-data-cleaning
# []
# lab-lambda-functions
# []

# %% [markdown]
# # Week 3

# %%
labs_week3 = {'lab-api-scavenger' : 'F3',
            'lab-web-scraping' : 'F4',
            'lab-pandas-deep-dive' : 'F5',
            'lab-advanced-regex' : 'F6',
            'lab-matplotlib-seaborn' : 'F7'}

# %%
for labs in labs_week3:
    print(labs)
    time.sleep(5)
    response = requests.get('https://api.github.com/repos/ta-data-lis/' + labs + '/pulls')
    data = pd.DataFrame(response.json())
    if 'title' in data:
        pr = data['title']
        pr_name = [a.split(']')[1].strip() for a in pr if len(a.split(']')) > 1]

        # print(pr)

        names = []

        for x in alias:
            for a in pr_name:
                if a.lower().find(x) != -1:
                    names.append(alias[x])

        print(names)

        book = openpyxl.load_workbook('labs.xlsx')

        for name in names:
            sheet = book[name]
            sheet[labs_week3[labs]] = 'Delivered'

        book.save('Labs.xlsx')
# Out:
# lab-api-scavenger
# []
# lab-web-scraping
# []
# lab-pandas-deep-dive
# ['barbara']
# lab-advanced-regex
# ['barbara']
# lab-matplotlib-seaborn
# []

# %% [markdown]
# # Week 4

# %%
labs_week4 = {'lab-intro-bi-tableau' : 'B13',
            'lab-bi-analysis-tableau' : 'B14',
            'lab-pivot-table-and-correlation' : 'B15',
            'Descriptive-Stats' : 'B16',
            'lab-regression-analysis' : 'B17',
            'lab-subsetting-and-descriptive-stats' : 'B18'}

# %%
for labs in labs_week4:
    print(labs)
    time.sleep(5)
    response = requests.get('https://api.github.com/repos/ta-data-lis/' + labs + '/pulls')
    data = pd.DataFrame(response.json())
    if 'title' in data:
        pr = data['title']
        pr_name = [a.split(']')[1].strip() for a in pr if len(a.split(']')) > 1]

        # print(pr)

        names = []

        for x in alias:
            for a in pr_name:
                if a.lower().find(x) != -1:
                    names.append(alias[x])

        print(names)

        book = openpyxl.load_workbook('labs.xlsx')

        for name in names:
            sheet = book[name]
            sheet[labs_week4[labs]] = 'Delivered'

        book.save('Labs.xlsx')
# Out:
# lab-intro-bi-tableau
# []
# lab-bi-analysis-tableau
# []
# lab-pivot-table-and-correlation
# []
# Descriptive-Stats
# []
# lab-regression-analysis
# ['eunice']
# lab-subsetting-and-descriptive-stats
# ['eunice']

# %% [markdown]
# # Week 5

# %%
labs_week5 = {'lab-intro-prob' : 'D13',
            'lab-probability-distributions' : 'D14',
            'M2-mini-project2' : 'D15',
            'lab-confidence-intervals' : 'D16',
            'lab-hypothesis-testing-1' : 'D17',
            'lab-hypothesis-testing-2' : 'D18',
            'lab-intro-to-scipy' : 'D19',
            'lab-two-sample-hyp-test' : 'D20',
            'lab-goodfit-indeptests' : 'D21'}

# %%
for labs in labs_week5:
    print(labs)
    time.sleep(5)
    response = requests.get('https://api.github.com/repos/ta-data-lis/' + labs + '/pulls')
    data = pd.DataFrame(response.json())
    if 'title' in data:
        pr = data['title']
        print(pr)
        pr_name = [a.split(']')[1].strip() for a in pr if len(a.split(']')) > 1]
        print(pr_name)

        # print(pr)

        names = []

        for x in alias:
            for a in pr_name:
                if a.lower().find(x) != -1:
                    names.append(alias[x])

        print(names)

        book = openpyxl.load_workbook('labs.xlsx')

        for name in names:
            sheet = book[name]
            sheet[labs_week5[labs]] = 'Delivered'

        book.save('Labs.xlsx')
# Out:
# lab-intro-prob
# 0     [lab-intro-prob] - Andre Pinto - November/Lisboa
# 1              Olha Popova introduction to probability
# 2                     [lab-intro-prob] - Rita Oliveira
# 3                              [lab-intro-prob]_AndreG
# 4                     lab Intro Prob - Beatriz Ramalho
# 5                        [lab-intro-prob] Rafael Silva
# 6                             [lab-intro-prob]-matheus
# 7                           [intro prb] Sidnei Andrade
# 8                        [lab-intro-prob] Filipe Costa
# 9              [lab-intro-prob] [renato] first attempt
# 10                           [lab-intro-prob] Bernardo
# 11                             [Lab intro prob] Joseph
# 12                                        arthurspriet
# 13                 [lab-intro-prob] Isabelle van Hoorn
# 14                             [lab-intro-prob] gladys
# 15                       [lab-intro-prob]GoncaloJardim
# 16                     [lab-intro-prob] Filipe Gardete
# ...
